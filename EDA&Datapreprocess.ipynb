# %% [markdown]
# ## Import Essential Libraries

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ## Set Up : Import Data Set

# %%
#Import data frame
main_heart_df = pd.read_csv('heart.csv')
main_heart_df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# ## Context of the Data Set

# %% [markdown]
# The Attributess include:
#
# 1 Age: age of the patient [years]
#
# 2 Sex: sex of the patient
# <pre>
#     [M: Male]
#     [F: Female]
# </pre>
#
# 3 ChestPainType: chest pain type
# <pre>
#     [TA: Typical Angina]
#     [ATA: Atypical Angina]
#     [NAP: Non-Anginal Pain]
#     [ASY: Asymptomatic]
# </pre>
#
# 4 RestingBP: resting blood pressure [mm Hg]
#
# 5 Cholesterol: serum cholesterol [mm/dl]
#
#
# 6 FastingBS: fasting blood sugar
# <pre>
#     [1: if FastingBS > 120 mg/dl]
#     [0: otherwise]
# </pre>
#
# 7 RestingECG: resting electrocardiogram results
# <pre>
#     [Normal: Normal]
#     [ST: having ST-T wave abnormality]
#     [LVH: showing probable or definite left ventricular hypertrophy]
# </pre>
#
#
# 8 MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
#
#
# 9 ExerciseAngina: exercise-induced angina (chest pain)
# <pre>
#     [Y: Yes]
#     [N: No]
# </pre>
#
# 10 Oldpeak: oldpeak = ST [Numeric value measured in depression]
#
#
# 11 ST_Slope: the slope of the peak exercise ST segment
# <pre>
#     [Up: upsloping]
#     [Flat: flat]
#     [Down: downsloping]
# </pre>
#
# 12 HeartDisease: output class
# <pre>
#     [1: heart disease]
#     [0: Normal]
# </pre>

# %% [markdown]
# ## Checking more information about the Variables

# %%
main_heart_df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
main_heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
main_heart_df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
main_heart_df.isnull().sum() # no NULL values
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# ## observations from the Imported dataset.
#
# There are 12 variables and 918 observations in the dataset.
#
# The **response variable** seems to be **'HeartDisease'** , while the remaining 11 are most likely predictors.
# <pre>
#     [1: heart disease]
#     [0: Normal]
# </pre>
#
# There are 5 predictor variables and it seems they are **Numeric**.
#
# <pre>
#     Age: age of the patient [years]
#
#     RestingBP: resting blood pressure [mm Hg]
#
#     Cholesterol: serum cholesterol [mm/dl]
#
#     MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
#
#     Oldpeak: oldpeak = ST [Numeric value measured in depression]
# </pre>
#
#
#
# The other 6 predictor variables identified are most likely **Categorical**.
# <pre>
#     Sex: sex of the patient
#
#     ChestPainType: chest pain type
#
#     FastingBS: fasting blood sugar
#
#     RestingECG: resting electrocardiogram results
#
#     ExerciseAngina: exercise-induced angina (chest pain)
#
#     ST_Slope: the slope of the peak exercise ST segment
# </pre>
#
# #### No Null Values Observed

# %% [markdown]
# ## Creating Numerical Dataframe

# %%
numDF = pd.DataFrame(main_heart_df[['Age','RestingBP','Cholesterol','MaxHR','Oldpeak']])
numDF.head()
# Out:
#    Age  RestingBP  Cholesterol  MaxHR  Oldpeak
# 0   40        140          289    172      0.0
# 1   49        160          180    156      1.0
# 2   37        130          283     98      0.0
# 3   48        138          214    108      1.5
# 4   54        150          195    122      0.0

# %% [markdown]
# ## Creating Categorical Dataframe

# %%
# convert the boolean column 'FastingBS' to a categorical column
main_heart_df['FastingBS'] = main_heart_df['FastingBS'].astype('object')

CatDF = pd.DataFrame(main_heart_df[['Sex','ChestPainType','FastingBS','RestingECG','ExerciseAngina','ST_Slope']])
CatDF.head()
# Out:
#   Sex ChestPainType FastingBS RestingECG ExerciseAngina ST_Slope
# 0   M           ATA         0     Normal              N       Up
# 1   F           NAP         0     Normal              N     Flat
# 2   M           ATA         0         ST              N       Up
# 3   F           ASY         0     Normal              Y     Flat
# 4   M           NAP         0     Normal              N       Up

# %%
main_heart_df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS          object
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %% [markdown]
# # Exploratory data analysis (EDA)

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# ### Distribution of "Heart Disease"

# %%
#Ploting "Heart Disease"

f = plt.figure(figsize=(24, 12))
sb.catplot( x="HeartDisease", kind="count", data = main_heart_df )

# %%
countG, countB = main_heart_df['HeartDisease'].value_counts()
print("Ratio of classes is YES : NO = ", countG, ":", countB)
# Out:
# Ratio of classes is YES : NO =  508 : 410

# %% [markdown]
# The Response data seems to be Class balanced.

# %% [markdown]
# ### Distribution of "Heart Disease" with respect to "Sex"

# %%
#Ploting "Heart Disease" with Male and Female.

f = plt.figure(figsize=(24, 12))
sb.catplot( x="HeartDisease", kind="count", data = main_heart_df , hue = "Sex")
plt.title('Distribution of "Heart Disease" with respect to "Sex"')
# Out:
# Text(0.5, 1.0, 'Distribution of "Heart Disease" with respect to "Sex"')

# %%
count0, count1 = main_heart_df['Sex'].value_counts()
print("Ratio of classes of Male : Female = ", count0, ":", count1)
print("Percentage of Males:", round((count0/(count0+count1)) * 100), "%")
print("Percentage of Females:", round((count1/(count0+count1)) * 100), "%")
# Out:
# Ratio of classes of Male : Female =  725 : 193
# Percentage of Males: 79 %
# Percentage of Females: 21 %

# %% [markdown]
# There are significantly more Males than Females in our dataset as Males take up about 79% of our dataset.

# %% [markdown]
# ### Distribution of "Heart Disease" with respect to "ChestPainType"

# %%
#Ploting "Heart Disease" with "ChestPainType".

f = plt.figure(figsize=(24, 12))
sb.catplot( x="HeartDisease", kind="count", data = main_heart_df , hue = "ChestPainType")
plt.title('Distribution of "Heart Disease" with respect to "ChestPainType"')
# Out:
# Text(0.5, 1.0, 'Distribution of "Heart Disease" with respect to "ChestPainType"')

# %% [markdown]
# Observation: Across all types of Chest pain, Individuals with ASY are most likely to get Heart Disease

# %% [markdown]
# ### Distribution of "Heart Disease" with respect to "FastingBS"

# %%
#Ploting "Heart Disease" with "FastingBS".

f = plt.figure(figsize=(24, 12))
sb.catplot( x="HeartDisease", kind="count", data = main_heart_df , hue = "FastingBS")
plt.title('Distribution of "Heart Disease" with respect to "FastingBS"')
# Out:
# Text(0.5, 1.0, 'Distribution of "Heart Disease" with respect to "FastingBS"')

# %% [markdown]
# Individuals who has Fasting Blood Sugar less than 120 mg/dl are less likely to get Heart Disease.

# %%
count0, count1 = main_heart_df['FastingBS'].value_counts()
print("Ratio of classes of Fasting Blood Sugar less than and more than 120 mg/dl = ", count0, ":", count1)
print("Percentage of Fasting Blood Sugar < 120 mg/dl :", round((count0/(count0+count1)) * 100), "%")
print("Percentage of Fasting Blood Sugar > 120 mg/dl:", round((count1/(count0+count1)) * 100), "%")
# Out:
# Ratio of classes of Fasting Blood Sugar less than and more than 120 mg/dl =  704 : 214
# Percentage of Fasting Blood Sugar < 120 mg/dl : 77 %
# Percentage of Fasting Blood Sugar > 120 mg/dl: 23 %

# %% [markdown]
# ### Distribution of "Heart Disease" with respect to "RestingECG"

# %%
#Ploting "Heart Disease" with "RestingECG".

f = plt.figure(figsize=(24, 12))
sb.catplot( x="HeartDisease", kind="count", data = main_heart_df , hue = "RestingECG")
plt.title('Distribution of "Heart Disease" with respect to "RestingECG"')
# Out:
# Text(0.5, 1.0, 'Distribution of "Heart Disease" with respect to "RestingECG"')

# %% [markdown]
# "RestingECG" does not seem to provide a conclusive intepretation if an indivisual is more likely to have "Heart Disease".

# %% [markdown]
# ### Distribution of "Heart Disease" with respect to "ExerciseAngina"

# %%
#Ploting "Heart Disease" with "ExerciseAngina".

f = plt.figure(figsize=(24, 12))
sb.catplot( x="HeartDisease", kind="count", data = main_heart_df , hue = "ExerciseAngina")
plt.title('Distribution of "Heart Disease" with respect to "ExerciseAngina"')
# Out:
# Text(0.5, 1.0, 'Distribution of "Heart Disease" with respect to "ExerciseAngina"')

# %% [markdown]
# It can be observed that indivisuals with "HeartDisease" have more likely to have "ExerciseAngina".
#
# It can be observed that indivisuals without "HeartDisease" have more likely to not have "ExerciseAngina".

# %% [markdown]
# ### Distribution of "Heart Disease" with respect to "ST_Slope"

# %%
#Ploting "Heart Disease" with "ST_Slope".

f = plt.figure(figsize=(24, 12))
sb.catplot( x="HeartDisease", kind="count", data = main_heart_df , hue = "ST_Slope")
plt.title('Distribution of "Heart Disease" with respect to "ST_Slope"')
# Out:
# Text(0.5, 1.0, 'Distribution of "Heart Disease" with respect to "ST_Slope"')

# %% [markdown]
# It can be observed that indivisuals with "HeartDisease" have more likely to have a flat "ST_Slope".
#
# It can be observed that indivisuals without "HeartDisease" have more likely to have a up "ST_Slope".

# %% [markdown]
# ## Numerical Data

# %% [markdown]
# ### Correlation Matrix

# %%
sb.heatmap(main_heart_df.corr() , vmin = -1, vmax = 1, annot = True, fmt=".2f")
plt.title('Correlation Matricx with Numerical Data')
# Out:
# Text(0.5, 1.0, 'Correlation Matricx with Numerical Data')

# %% [markdown]
# From the correlation matrix above, the top 5 numerical data with the highest correlation with "HeartDisease":
#
#
#
# "MaxHR" has the highest negative correlation -0.40 with "HeartDisease".
#
# "Cholesterol" has a somewhat negative correlation of-0.23 with "HeartDisease".
#
#
# "Oldpeak" had the highest positive correlation of 0.40 with "HeartDisease".
#
# "Age" has a somewhat positive correlation of 0.28 respectively with "HeartDisease".

# %% [markdown]
# ### BoxPlot | Histplot | ViolinPlot

# %%
f, axes = plt.subplots(5, 3, figsize=(18, 24))

count = 0
for var in numDF:
    sb.boxplot(data = numDF[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = numDF[var], ax = axes[count,1])
    sb.violinplot(data = numDF[var], orient = "h", ax = axes[count,2])
    
    count += 1

# %% [markdown]
# It can be observed that "RestingBP","Cholesterol","MaxHR" and "Oldpeak" contains outliers.

# %% [markdown]
# ### Presence of "Missing" Data Imputed with Zero Value.

# %% [markdown]
# Based on the obseravtion above,'RestingBP' and 'Cholesterol have zero value'
#
#
#
# We know that it is impossible for a person to have zero 'RestingBP' or 'Cholesterol. Hence the missing values in the data set have alreaday been imputed with zero values.

# %%
bp_df = pd.DataFrame(main_heart_df['RestingBP'])
bp_df = bp_df[bp_df['RestingBP'] == 0].count()
bp_df
# Out:
# RestingBP    1
# dtype: int64

# %%
ca_df = pd.DataFrame(main_heart_df['Cholesterol'])
ca_df = ca_df[ca_df['Cholesterol'] == 0].count()
ca_df
# Out:
# Cholesterol    172
# dtype: int64

# %% [markdown]
# ### Presence of Outliers in Dataset.

# %%
count = 0
for var in numDF:
    Q1 = numDF[var].quantile(0.25)
    Q3 = numDF[var].quantile(0.75)
    IQR = Q3-Q1
    lower_lim = Q1 - 1.5 * IQR
    upper_lim = Q3 + 1.5 * IQR
    outliers_low = (numDF[var] < lower_lim)
    outliers_up = (numDF[var] > upper_lim)
    
    print('Number of Outliers in %s is :' %(var),len(numDF[var][outliers_low]) + len(numDF[var][outliers_up]))
    print("")
    count += 1
# Out:
# Number of Outliers in Age is : 0
#
# Number of Outliers in RestingBP is : 28
#
# Number of Outliers in Cholesterol is : 183
#
# Number of Outliers in MaxHR is : 2
#
# Number of Outliers in Oldpeak is : 16

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Evaluation of the presence of "Missing" Data imputed with Zero

# %% [markdown]
# The number of "RestingBP" == 0  is 1.
#
# The number of "Cholesterol" == 0  is 172.
#
# It is fine to drop the row where "RestingBP" == 0 Since it is only a single row.
#
# Dropping the rows 'Cholesterol' == 0 is approximately 19% of our initial data. It might be better to see if we can use imputation in order to handle this issue.

# %% [markdown]
# #### Dropping Rows with "RestingBP" == 0

# %%
# delete a single row by index value 449
main_heart_df = main_heart_df.drop(labels=449, axis=0).reset_index(drop=True)

# %% [markdown]
# ## Cleaning Data Strategy

# %% [markdown]
# 1) Create 2 additional dataframe imputed with the mean and median of 'Cholesterol'.
#
# 2) We will then be creating 3 Seperate Dataframe of the same imputation without outliers.
#
# 3) Finally we will compare the accuracy of the models within imputation and Across imoutation to find the best model to find a classification.

# %% [markdown]
# ## Creating DataFrames for zero/mean/median imputation with outliers

# %% [markdown]
# #### Zero Imputation

# %%
# For zero imputation : IPzero_heart_df 
#main_heart_df already is already imputed with Zero values. 

IPzero_heart_df = main_heart_df.copy()


f, axes = plt.subplots(1, 2, figsize=(30, 10))
sb.boxplot(data = IPzero_heart_df['Cholesterol'], orient = "h", ax = axes[0])
sb.histplot(data = IPzero_heart_df['Cholesterol'], ax = axes[1])
# Out:
# <AxesSubplot:xlabel='Cholesterol', ylabel='Count'>

# %%
sb.heatmap(IPzero_heart_df.corr() , vmin = -1, vmax = 1, annot = True, fmt=".2f")
plt.title('Correlation Matricx with Numerical Data')
# Out:
# Text(0.5, 1.0, 'Correlation Matricx with Numerical Data')

# %% [markdown]
# No Expected change to Correlation matrix.

# %% [markdown]
# #### Mean Imputation

# %%
# For mean imputation : IPmean_heart_df
# Replacing '0' values in cholestrol column with mean value

# New dataframe IPmean_heart_df
IPmean_heart_df = main_heart_df.copy()

# create SimpleImputer object
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=0, strategy='mean')

# fit imputer to 'cholesterol' column
imputer.fit(IPmean_heart_df[['Cholesterol']])

# transform 'cholesterol' column by replacing 0 with mean value
IPmean_heart_df['Cholesterol'] = imputer.transform(IPmean_heart_df[['Cholesterol']])

mean_value = imputer.statistics_[0]
# Print the mean value
print('Mean value of Cholesterol column:', mean_value)

f, axes = plt.subplots(1, 2, figsize=(30, 10))
sb.boxplot(data = IPmean_heart_df['Cholesterol'], orient = "h", ax = axes[0])
sb.histplot(data = IPmean_heart_df['Cholesterol'], ax = axes[1])
# Out:
# Mean value of Cholesterol column: 244.6353887399464
# <AxesSubplot:xlabel='Cholesterol', ylabel='Count'>

# %%
ca_df = pd.DataFrame(IPmean_heart_df['Cholesterol'])
ca_df[ca_df['Cholesterol'] == 0].count()
# Out:
# Cholesterol    0
# dtype: int64

# %% [markdown]
# Mean data successfully imputed

# %%
sb.heatmap(IPmean_heart_df.corr() , vmin = -1, vmax = 1, annot = True, fmt=".2f")
plt.title('Correlation Matricx with Numerical Data')
# Out:
# Text(0.5, 1.0, 'Correlation Matricx with Numerical Data')

# %% [markdown]
# **when compared to Zero imputation :**
#
# The correlation of 'Cholesterol' dropped from 0.23 to 0.09 (Taking abosulte Values).
#
# It might suggest that 'Cholesterol' might have a weaker correlation to our response variable.

# %% [markdown]
# #### Median Imputation

# %%
# For median imputation : IPmedian_heart_df
# Replacing '0' values in cholestrol column with median value

# New dataframe IPmean_heart_df
IPmedian_heart_df = main_heart_df.copy()

# create SimpleImputer object
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=0, strategy='median')

# fit imputer to 'cholesterol' column
imputer.fit(IPmedian_heart_df[['Cholesterol']])

# transform 'cholesterol' column by replacing 0 with mean value
IPmedian_heart_df['Cholesterol'] = imputer.transform(IPmedian_heart_df[['Cholesterol']])

median_value = imputer.statistics_[0]
# Print the median value
print('Median value of Cholesterol column:', median_value)

f, axes = plt.subplots(1, 2, figsize=(30, 10))
sb.boxplot(data = IPmedian_heart_df['Cholesterol'], orient = "h", ax = axes[0])
sb.histplot(data = IPmedian_heart_df['Cholesterol'], ax = axes[1])
# Out:
# Median value of Cholesterol column: 237.0
# <AxesSubplot:xlabel='Cholesterol', ylabel='Count'>

# %%
ca_df = pd.DataFrame(IPmedian_heart_df['Cholesterol'])
ca_df[ca_df['Cholesterol'] == 0].count()
# Out:
# Cholesterol    0
# dtype: int64

# %% [markdown]
# Median data successfully imputed

# %%
sb.heatmap(IPmedian_heart_df.corr() , vmin = -1, vmax = 1, annot = True, fmt=".2f")
plt.title('Correlation Matricx with Numerical Data')
# Out:
# Text(0.5, 1.0, 'Correlation Matricx with Numerical Data')

# %% [markdown]
# **when compared to Zero imputation :**
#
# The correlation of 'Cholesterol' has similarly dropped from 0.23 to 0.08 (Taking abosulte Values).
#
# **when compared to mean imputation :**
#
# The correlation of 'Cholesterol' has similarly dropped from 0.09 to 0.08 (Taking abosulte Values).
#
# It might suggest that difference in imputation technique of mean and median might not significant.

# %% [markdown]
# ## Creating DataFrames for zero/mean/median imputation without outliers

# %% [markdown]
# #### Defining remove_outlier Function

# %%
# define a function called "Outliers" which returns a list of outliers 
# IQR = Q3-Q1
# +/- 1.5* IQR

def remove_outliers(df):
    num_cols = df.select_dtypes(include=[np.number]).columns
    cat_cols = df.select_dtypes(exclude=[np.number]).columns
    
    Q1 = df[num_cols].quantile(0.25)
    Q3 = df[num_cols].quantile(0.75)
    
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outlier_mask = ((df[num_cols] < lower_bound) | (df[num_cols] > upper_bound)).any(axis=1)
    
    return df.loc[~outlier_mask, :]

# %% [markdown]
# #### Defining num_outlier Function

# %%
# define a fucntion to print the number of outliers called "num_outliers".
def num_outliers(df):
    count = 0
    for var in numDF:
        Q1 = numDF[var].quantile(0.25)
        Q3 = numDF[var].quantile(0.75)
        IQR = Q3-Q1
        lower_lim = Q1 - 1.5 * IQR
        upper_lim = Q3 + 1.5 * IQR
        outliers_low = (numDF[var] < lower_lim)
        outliers_up = (numDF[var] > upper_lim)
    
        print('Number of Outliers in %s is :' %(var),len(numDF[var][outliers_low]) + len(numDF[var][outliers_up]))
        print("")
        count += 1
    
    return

# %% [markdown]
# #### Zero Imputation without outliers

# %%
# Deleting Outliers and creating new Dataframe IPzero_N0_outliers_heart_df
IPzero_N0_outliers_heart_df = IPzero_heart_df.copy()

IPzero_N0_outliers_heart_df = remove_outliers(IPzero_N0_outliers_heart_df).reset_index(drop=True)

# creating numDF to visualise
numDF = pd.DataFrame(IPzero_N0_outliers_heart_df[['Age','RestingBP','Cholesterol','MaxHR','Oldpeak']])

# Remaining Outliers
num_outliers(numDF)
# Out:
# Number of Outliers in Age is : 0
#
# Number of Outliers in RestingBP is : 0
#
# Number of Outliers in Cholesterol is : 10
#
# Number of Outliers in MaxHR is : 0
#
# Number of Outliers in Oldpeak is : 0

# %% [markdown]
# There appears to be have remaining outlier in Cholesterol.
#
# We are keeping the remaining outliers as could be that they represent valid and important data points in this dataset that could provide valuable insights into the problem you are trying to solve. For example, some extreme values of a 'Cholesterol'  could be indicative of a rare or unique condition that we may want to capture in our analysis.
#
# Also the remaining outliers are not necessarily erroneous or inconsistent data points, but rather represent extreme values that are plausible and consistent. In this case, removing the remaining outliers could potentially result in a loss of important information and potentially impact the accuracy of your analysis.
#
# Hence we are keeping the remaining outliers.

# %%
#Deleting Outliers
    
# creating numDF to visualise
numDF = pd.DataFrame(IPzero_N0_outliers_heart_df[['Age','RestingBP','Cholesterol','MaxHR','Oldpeak']])

# Plot grpahs
f, axes = plt.subplots(5, 3, figsize=(18, 24))
count = 0
for var in numDF:
    sb.boxplot(data = numDF[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = numDF[var], ax = axes[count,1])
    sb.violinplot(data = numDF[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
IPzero_heart_df.shape
# Out:
# (917, 12)

# %%
IPzero_N0_outliers_heart_df.shape
# Out:
# (702, 12)

# %% [markdown]
# 225 rows are deleted.Removal of Outliers successful.

# %%
sb.heatmap(IPzero_N0_outliers_heart_df.corr() , vmin = -1, vmax = 1, annot = True, fmt=".2f")
plt.title('Correlation Matricx with Numerical Data')
# Out:
# Text(0.5, 1.0, 'Correlation Matricx with Numerical Data')

# %% [markdown]
# **when compared to Zero imputation with Outliers  :**
#
#
#     2 Notable observation can be made
#
#     'Cholesterol':
#
#     The correlation of 'Cholesterol' has  dropped from 0.23 to 0.09 (Taking abosulte Values).
#
#     This might further suggest that 'Cholesterol' is weakly correlated to our response variable.
#
#
#     'Oldpeak':
#
#     The correlation of 'Oldpeak' has similarly increased from 0.40 to 0.50 (Taking abosulte Values).
#
#     This might suggest that 'FastingBS' has a slighly higher correlation to our response variable.

# %% [markdown]
# #### mean Imputation without outliers

# %%
IPmean_N0_outliers_heart_df = IPmean_heart_df.copy()

# For mean imputation : IPmean_N0_outliers_heart_df

# Deleting Outliers and creating new Dataframe IPmean_N0_outliers_heart_df    
IPmean_N0_outliers_heart_df = remove_outliers(IPmean_N0_outliers_heart_df).reset_index(drop=True)

# creating numDF to visualise
numDF = pd.DataFrame(IPmean_N0_outliers_heart_df[['Age','RestingBP','Cholesterol','MaxHR','Oldpeak']])

# Remaining Outliers
num_outliers(numDF)
# Out:
# Number of Outliers in Age is : 0
#
# Number of Outliers in RestingBP is : 0
#
# Number of Outliers in Cholesterol is : 15
#
# Number of Outliers in MaxHR is : 0
#
# Number of Outliers in Oldpeak is : 0

# %% [markdown]
# Similarly, we will be keeping the outliers as stated above.

# %%
# Plot grpahs
f, axes = plt.subplots(5, 3, figsize=(18, 24))
count = 0
for var in numDF:
    sb.boxplot(data = numDF[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = numDF[var], ax = axes[count,1])
    sb.violinplot(data = numDF[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
IPmean_heart_df.shape
# Out:
# (917, 12)

# %%
IPmean_N0_outliers_heart_df.shape
# Out:
# (836, 12)

# %% [markdown]
# 81 rows are deleted.Removal of Outliers successful.

# %%
sb.heatmap(IPmean_N0_outliers_heart_df.corr() , vmin = -1, vmax = 1, annot = True, fmt=".2f")
plt.title('Correlation Matricx with Numerical Data')
# Out:
# Text(0.5, 1.0, 'Correlation Matricx with Numerical Data')

# %% [markdown]
# **when compared to mean imputation with Outliers  :**
#
#     Predictor variables :'MaxHR' and 'Oldpeak':
#     All had a slight and insignificant increase of '0.1' (Taking abolute value) in correlation to the response variable.
#
#     Predictor variables :'RestingBP':
#     had a slight and insignificant decrease of '0.1' (Taking abolute value) in correlation to the response variable.
#
#     Predictor variables :'Cholesterol':
#     had a slight and insignificant decrease of '0.1' (Taking abolute value) in correlation to the response variable.

# %% [markdown]
# #### median Imputation without outliers

# %%
# For median imputation : IPmedian_N0_outliers_heart_df
IPmedian_N0_outliers_heart_df = IPmedian_heart_df.copy()

# Deleting Outliers and creating new Dataframe IPmedian_N0_outliers_heart_df    
IPmedian_N0_outliers_heart_df = remove_outliers(IPmedian_N0_outliers_heart_df).reset_index(drop=True)

# creating numDF to visualise
numDF = pd.DataFrame(IPmedian_N0_outliers_heart_df[['Age','RestingBP','Cholesterol','MaxHR','Oldpeak']])


# Print no of outliers
num_outliers(numDF)
# Out:
# Number of Outliers in Age is : 0
#
# Number of Outliers in RestingBP is : 0
#
# Number of Outliers in Cholesterol is : 15
#
# Number of Outliers in MaxHR is : 0
#
# Number of Outliers in Oldpeak is : 0

# %% [markdown]
# Similarly, we will be keeping the outliers as stated above.

# %%
# Plot grpahs
f, axes = plt.subplots(5, 3, figsize=(18, 24))
count = 0
for var in numDF:
    sb.boxplot(data = numDF[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = numDF[var], ax = axes[count,1])
    sb.violinplot(data = numDF[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
IPmedian_heart_df.shape
# Out:
# (917, 12)

# %%
IPmedian_N0_outliers_heart_df.shape
# Out:
# (836, 12)

# %% [markdown]
# 81 rows are deleted.Removal of Outliers successful.

# %%
sb.heatmap(IPmedian_N0_outliers_heart_df.corr() , vmin = -1, vmax = 1, annot = True, fmt=".2f")
plt.title('Correlation Matricx with Numerical Data')
# Out:
# Text(0.5, 1.0, 'Correlation Matricx with Numerical Data')

# %% [markdown]
# **when compared to median imputation with Outliers  :**
#
#     Predictor variables : 'Age' , 'RestingBP' , 'MaxHR' , 'OldPeak':
#     had a slight and insignificant decrease of '0.1' (Taking abolute value) in correlation to the response variable.
#
#     Predictor variables :'Cholesterol':
#     had a slight and insignificant increase of '0.1' (Taking abolute value) in correlation to the response variable.
#
#
#
# **Similar findings** with comparison between **mean imputation without outliers and median imputation without outliers**.
#
# This further implies that there **isnt much difference in the significance of mean and median imputation**.

# %% [markdown]
# ### Observation comparing correlation matrix across Imputation

# %% [markdown]
# Across all imputation , it seems that **'Age' , 'MaxHR' and 'Oldpeak'** has the **stronger correlation** to 'HeartDisease'.
# <br>
#
# while **'RestingBP' and 'Cholesterol'** seems to be a **weaker correlation** to 'HeartDisease' especially after the removal of outliers.<br>
#
# Furthermore , there is a notable difference in the change of correlation between zero and mean/median imputation. However there doesnt seem to be much of a difference in the change of correlation between mean and median imputation.

# %% [markdown]
# ## Final Evaluation

# %% [markdown]
# We can observe as we imputate the values with the mean or median, cholestrol's absolute correlation with Heart Disease decreases.<br> This is expected as the mean and the median values used for imputation are likely to be skewed due to the large number of 0 values. <br> Hence, we move to remove the zero values and other outliers to acheive better imputation <br><br>
#
# Interestingly, we can observe that the removal of outliers did not affect the correlation of cholestrol and HeartDisease a lot (+0.06 to +0.07).<br> Hence by cleaning the data this way we can conlcude that cholesterol is a poor indicator of heart disease for this dataset.<br> Hence we can choose to ignore cholestrol as a factor when checking for heart disease in this dataset. <br>However, we would be keeping it and compare the accuracy of imputation within and across the four models to come to a concrete conclusion. <br><br>
#
#
#
# Medical literature agrees with our findings as cholesterol is listed as a risk factor for heart disease and not necessarily a definitive indicator of heart disease on its own.
